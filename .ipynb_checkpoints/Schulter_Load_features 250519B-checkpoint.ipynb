# %%
try:
    from code.schultercore import *
except ImportError:
    from schultercore import *   # when running from terminal, the directory may not be identified as a packagefrom keras.callbacks import ModelCheckpoint
# schultercore.py has additional functions
import os, shutil, librosa
import numpy as np
import time
import matplotlib.pyplot as plt
import h5py
import csv
import math
# Out:
# Using TensorFlow backend.

# %%
params=load_parameters()
# Out:
# /Users/brendanoconnor/Desktop/APP/MXX-git2-/SchulterReproduction/schultercore.py:22: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   return yaml.load(open('params.yaml'))

# %% [markdown]
# # Setup Directory

# %%
os.getcwd()
# Out:
# '/Users/brendanoconnor/Desktop/APP/MXX-git2-/SchulterReproduction'

# %%
# src_path = '/Users/brendanoconnor/Desktop/APP/MXX-git2-/jamendo/audio'
# dst_path = '/Users/brendanoconnor/Desktop/APP/MXX-git2-/jamendo/audioConverted'

# %%
# if not os.path.isdir(src_path):
#     print('ERROR! source directory does not exist!: ', src_path)
# if not os.path.isdir(dst_path):
#     print('ERROR! Destination directory does not exist!: ', dst_path)
# if not os.path.isfile(track_path):
#     print('ERROR! File doesnt exist: ', track_path)

# %%
print('gathering files...')
train_dir = 'jamendo/audioTrain/'
train_files = [train_dir + x for x in os.listdir(train_dir) if x.endswith('.wav') or x.endswith('.ogg') or x.endswith('.mp3')]
val_dir = 'jamendo/audioVal/'
val_files = [val_dir + x for x in os.listdir(val_dir) if x.endswith('.wav') or x.endswith('.ogg') or x.endswith('.mp3')]
test_dir = 'jamendo/audioTest/'
test_files = [test_dir + x for x in os.listdir(test_dir) if x.endswith('.wav') or x.endswith('.ogg') or x.endswith('.mp3')]
print(len(train_files), 'train files \n', len(val_files), 'validation files \n', len(test_files), 'test files')

test_folder_dir= 'jamendo/testFolder/'
test_folder_files = [test_folder_dir + x for x in os.listdir(test_folder_dir) if x.endswith('.wav') or x.endswith('.ogg') or x.endswith('.mp3')]
# Out:
# gathering files...
# 61 train files
#  16 validation files
#  16 test files

# %% [markdown]
# # Create hdf5

# %%
print('setting up hdf5 file...')
# Out:
# setting up hdf5 file...

# %%
num_train_instances = len(train_files)
num_val_instances = len(val_files)

# %%
image_height=params['n_mel']
image_width=int(np.round(params['max_song_length'] * params['fs'] / float(params['hop_length'])))

# %%
image_width
# Out:
# 29260

# %%
dataset = h5py.File('jamendo/dataset2.hdf5', mode='w')

# %%
dataset.create_dataset('train_labels',
                       shape=(num_train_instances, 1),
                       dtype=np.int)
dataset.create_dataset('val_labels',
                       shape=(num_val_instances, 1),
                       dtype=np.int)
# we store one image per instance of size image_height x image_width holding floating point numbers
dataset.create_dataset('train_features',
                       shape=(num_train_instances, image_height, image_width+1),
                       dtype=np.float)
dataset.create_dataset('val_features',
                       shape=(num_val_instances, image_height, image_width+1),
                       dtype=np.float)
# Out:
# <HDF5 dataset "val_features": shape (16, 80, 29261), type "<f8">

# %% [markdown]
# # Define Extract Feature function

# %% [markdown]
# # Extract features and store in HDF5

# %%
# TRAIN SET
print('working on train set...')
name_length_list=[]

for k, audio_path in enumerate(train_files):
    print('  ', k + 1, '/', len(train_files), audio_path)
    # extract the feature
    feature, audio_melframe_nums = extract_feature(audio_path, params)
    name_length_list.append([os.path.basename(audio_path),audio_melframe_nums])
    plot_save_feature(feature, os.path.basename(audio_path))
    # we can deduce the label from the file name
    dataset['train_features'][k, ...] = feature
    
with open('jamendo/trainSongLength.csv', 'w') as csvFile:
    writer = csv.writer(csvFile)
    writer.writerows(name_length_list)
csvFile.close()
# Out:
# working on train set...
#    1 / 2 jamendo/testFolder/01 - The Final Rewind.ogg
# Track samplerate:  22050
# Track sample size:  6069472
# (80, 29261)
#    2 / 2 jamendo/testFolder/01 - A better Life.ogg
# Track samplerate:  22050
# Track sample size:  5024096
# (80, 29261)

# %%
# TRAIN SET
print('working on validation set...')
name_length_list=[]

for k, audio_path in enumerate(val_files):
    print('  ', k + 1, '/', len(val_files), audio_path)
    # extract the feature
    feature, audio_melframe_nums = extract_feature(audio_path)
    name_length_list.append([os.path.basename(audio_path),audio_melframe_nums])
    plot_save_feature(feature, os.path.basename(audio_path))
    # we can deduce the label from the file name
    dataset['val_features'][k, ...] = feature
    
with open('jamendo/valSongLength.csv', 'w') as csvFile:
    writer = csv.writer(csvFile)
    writer.writerows(name_length_list)
csvFile.close()
# Out:
# working on validation set...
#    1 / 16 jamendo/audioVal/05 - Anyway.ogg
# Track samplerate:  22050
# Track sample size:  4104608
# (80, 29261)
#    2 / 16 jamendo/audioVal/05 - Bleu horizon.ogg
# Track samplerate:  22050
# Track sample size:  3527648
# (80, 29261)
#    3 / 16 jamendo/audioVal/05 - Aux Cieux, Tu es mon Dieu.ogg
# Track samplerate:  22050
# Track sample size:  5328224
# (80, 29261)
#    4 / 16 jamendo/audioVal/05 - Animal.ogg
# Track samplerate:  22050
# Track sample size:  4862304
# (80, 29261)
#    5 / 16 jamendo/audioVal/05 - As Longas Passagens.ogg
# Track samplerate:  22050
# Track sample size:  4572960
# (80, 29261)
#    6 / 16 jamendo/audioVal/05 - Black Box.ogg
# Track samplerate:  22050
# Track sample size:  6209056
# (80, 29261)
#    7 / 16 jamendo/audioVal/05 - Au Mage.ogg
# Track samplerate:  22050
# Track sample size:  3296992
# (80, 29261)
#    8 / 16 jamendo/audioVal/05 - Argeles.ogg
# Track samplerate:  22050
# Track sample size:  6479584
# (80, 29261)
#    9 / 16 jamendo/audioVal/05 - Change.ogg
# Track samplerate:  22050
# Track sample size:  7763808
# (80, 29261)
#    10 / 16 jamendo/audioVal/05 - Cecilia.ogg
# Track samplerate:  22050
# Track sample size:  6971744
# (80, 29261)
#    11 / 16 jamendo/audioVal/05 - Bucle Paranoideal.ogg
# Track samplerate:  22050
# Track sample size:  5556806
# (80, 29261)
#    12 / 16 jamendo/audioVal/05 - Bazooka enraye.ogg
# Track samplerate:  22050
# Track sample size:  3978784
# (80, 29261)
#    13 / 16 jamendo/audioVal/05 - Bandicape.ogg
# Track samplerate:  22050
# Track sample size:  4263456
# (80, 29261)
#    14 / 16 jamendo/audioVal/05 - Budenzauber.ogg
# Track samplerate:  22050
# Track sample size:  4007648
# (80, 29261)
#    15 / 16 jamendo/audioVal/05 - Callypige palindrome.ogg
# Track samplerate:  22050
# Track sample size:  6846752
# (80, 29261)
#    16 / 16 jamendo/audioVal/05 - Angeliques.ogg
# Track samplerate:  22050
# Track sample size:  2634208
# (80, 29261)
